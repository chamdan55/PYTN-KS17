# %% [markdown]
# # Conditional

# %%
x = 0
y = 5

if x < y:
    print('yes')
# Out:
# yes

# %%
if x:
    print('yes')

# %%
if y:
    print('yes')
# Out:
# yes

# %%
y = -3

if x:
    print('yes')
    print('ok')
# Out:
# ok

# %%
if 'foo' in ['bar', 'baz', 'qux', 'foo']:
    print('Expression was True')
    print('Executing statement in suite')
    print('...')
    print('Done')
    
print('After Conditional')
# Out:
# Expression was True
# Executing statement in suite
# ...
# Done
# After Conditional

# %%
if 'foo' in ['bar', 'baz', 'foo']:
    print('Outer condition is True')
    
    if 10 > 20:
        print('Inner Condition 1')
    
    if 10 < 20:
        print('Inner Condition 2')
    
    print('End of Outer Condition')
    
print('After Conditional')
# Out:
# Outer condition is True
# Inner Condition 2
# End of Outer Condition
# After Conditional

# %% [markdown]
# ## The Else Elif clause

# %%
x = 60

if x < 50: print('(first suite)'); print('x is small')
else :
    print('(second suite)')
    print('x is large')
# Out:
# (second suite)
# x is large

# %%
hargaBuku = 20000
hargaMajalah = 5000
uang = 2000

if uang > hargaBuku:
    print('beli Buku')
else :
    print('uang tidak cukup')
# Out:
# uang tidak cukup

# %%
hargaBuku = 20000
hargaMajalah = 5000
uang = 2000

if uang > hargaBuku:
    print('beli Buku')
elif uang > hargaMajalah:
    print('beli Majalah')
else :
    print('uang tidak cukup')
# Out:
# uang tidak cukup

# %%
name = 'Hacktiv8'

if name=='Fred':
    print('Hello Fred!')
elif name=='Xander':
    print('Hello Xander')
elif name=='Hacktiv8':
    print('Hello Hacktiv8')
elif name=='Arnorld':
    print('Hello Arnold')
else :
    print("I don't know who you are!")
# Out:
# Hello Hacktiv8

# %%
if 'a' in 'bar':
    print('foo')
# Out:
# foo

# %% [markdown]
# ## One Line If Statement

# %%
if '' in 'foo': print('1'); print('2'); print('3')

# %%
x = 2

if x==1 : print('foo'); print('bar'); print('baz')
elif x==2 : print('qux'); print('quux')
else : print('corge'); print('grault')
# Out:
# qux
# quux

# %% [markdown]
# ## Conditional Expression

# %% [markdown]
# ![image.png](attachment:52e9f1af-e2e2-4425-a95c-f97cbf5252e1.png)

# %%
raining = False
print('Lets go to the', 'beach' if not raining else 'library')
# Out:
# Lets go to the beach

# %%
raining = True
print('Lets go to the', 'beach' if not raining else 'library')
# Out:
# Lets go to the library

# %%
age = 12
s = 'teen' if age<21 else 'adult'

# %%
s
# Out:
# 'teen'

# %%
'yes' if ('qux' in ['foo', 'bar', 'baz']) else 'no'
# Out:
# 'no'

# %% [markdown]
# ## The Python Pass Statement

# %%
if 1 :
    pass
print('foo')
# Out:
# foo

# %% [markdown]
# # Python "while" loop

# %%
n = 5
while n > 0:
    n -= 1
    print(n)
# Out:
# 4
# 3
# 2
# 1
# 0

# %%
i = 1
while i < 6:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Break and Continue

# %% [markdown]
# ![image.png](attachment:6eda34df-e6b2-4c8b-8eab-4c9ba85b3d2b.png)

# %%
n = 5
while n > 0:
    n -= 1
    if n == 2:
        break
    print(n)
print('Loop Ended.')
# Out:
# 4
# 3
# Loop Ended.

# %%
n = 5
while n > 0:
    n -= 1
    if n == 2:
        continue
    print(n)
print('Loop Ended.')
# Out:
# 4
# 3
# 1
# 0
# Loop Ended.

# %% [markdown]
# ## Else clause

# %%
n = 5
while n > 0:
    n -= 1
    print(n)
else :
    print('Loop Ended.')
# Out:
# 4
# 3
# 2
# 1
# 0
# Loop Ended.

# %%
n = 5
while n > 0:
    n -= 1
    print(n)
    if n == 2:
        break
else :
    print('Loop Ended.')
# Out:
# 4
# 3
# 2

# %% [markdown]
# ## Infinite Loop

# %%
# while True:
#     print('foo')

# %% [markdown]
# ## Nested while loop

# %%
a = ['foo', 'bar']

while len(a):
    print(a.pop(0))
    
    b = ['baz', 'qux']
    while len(b):
        print('>', b.pop(0))
# Out:
# foo
# > baz
# > qux
# bar
# > baz
# > qux

# %% [markdown]
# ![image.png](attachment:d6bb93f0-0e3f-4303-b884-b33cda08f1f3.png)

# %% [markdown]
# ![image.png](attachment:75ef6e6e-de98-4e3d-b748-5bb77c265673.png)

# %% [markdown]
# ## One-line while Loop

# %%
n = 5

while n > 0: n-=1; print(n)
# Out:
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# # Definite Iteration in Progrmamming

# %% [markdown]
# ![image.png](attachment:5ff46b04-759a-4272-8486-897f5ae3866a.png)
# ![image.png](attachment:57de0c28-b592-4509-83e9-909d102167ec.png)
# ![image.png](attachment:e934a6d6-8d8b-4c65-a188-2798564d9208.png)

# %% [markdown]
# ## for Loop

# %% [markdown]
# ![image.png](attachment:c1ba3091-d485-42bf-9381-44f599d545ce.png)

# %%
a = ['foo', 'bar', 'baz']

for val in a:
    print(val)
# Out:
# foo
# bar
# baz

# %% [markdown]
# ## loop with Dict

# %%
d = {'foo' : 1,
     'bar' : 2,
     'baz' : 3}

# %%
for k in d:
    print(k)
# Out:
# foo
# bar
# baz

# %%
d['bar']
# Out:
# 2

# %%
for k in d:
    print(d[k])
# Out:
# 1
# 2
# 3

# %%
for k in d.values():
    print(k)
# Out:
# 1
# 2
# 3

# %%
for k, v in d.items():
    print(k, ':', v)
# Out:
# foo : 1
# bar : 2
# baz : 3

# %% [markdown]
# ## Loop with Range

# %%
for n in (0, 1, 2, 3, 4):
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for n in range(6):
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Altering Loop behaviour

# %%
for i in ['foo', 'bar', 'baz', 'qux']:
    if 'b' in i:
        break
    print(i)
# Out:
# foo

# %%
for i in ['foo', 'bar', 'baz', 'qux']:
    if 'b' in i:
        continue
    print(i)
# Out:
# foo
# qux

# %% [markdown]
# ## Else Clause

# %%
for i in ['foo', 'bar', 'baz', 'qux']:
    print(i)
else : 
    print('Done')
# Out:
# foo
# bar
# baz
# qux
# Done

# %%
for i in ['foo', 'bar', 'baz', 'qux']:
    if 'bar' == i:
        break
    print(i)
else : 
    print('Done')
# Out:
# foo

# %% [markdown]
# ## Example

# %%
temp = input('Ketikan Temperatur yang ingin dikonversi, eg. 45F, 120C: ')
degree = int(temp[:-1])
satuan = temp[-1].upper()

if satuan == 'C':
    result = int(round((9 * degree) / 5 + 32))
elif satuan == 'F':
    result = int(round((degree - 32) + 5/ 9))
else : 
    print('Masukan input yang benar')
    
print('Temperaturnya adalah', result, 'derajat')
# Out:
# Ketikan Temperatur yang ingin dikonversi, eg. 45F, 120C:  45F
# Temperaturnya adalah 14 derajat

# %%
while True:
    msg = input('Ketikan karakter: ').lower()
    print(msg)
    if msg == 'stop':
        break
# Out:
# Ketikan karakter:  test
# test
# Ketikan karakter:  hacktiv
# hacktiv
# Ketikan karakter:  jakdkf
# jakdkf
# Ketikan karakter:  stop
# stop
